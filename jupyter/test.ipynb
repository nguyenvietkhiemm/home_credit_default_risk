# %%
from config import ROOT
from config import paths

import os


for name, path in paths.items():
    if os.path.isfile(path):
        print(f"{name}: tồn tại")
    else:
        print(f"{name}: không tồn tại")
# Out:
# train: tồn tại
# test: tồn tại
# prev: tồn tại
# installments: tồn tại
# credit_card: tồn tại
# pos_cash: tồn tại
# bureau: tồn tại
# bureau_balance: tồn tại
# description: tồn tại

# %%
from modules.utils import get_pickle

train = get_pickle("train")

# %%
# from config import reload_config
# reload_config()

from config import reload
reload()
from config import use_cols

# %%
use_cols
# Out:
# ['SK_ID_CURR',
#  'AMT_INCOME_TOTAL',
#  'AMT_CREDIT',
#  'AMT_ANNUITY',
#  'AMT_GOODS_PRICE',
#  'DAYS_BIRTH',
#  'DAYS_EMPLOYED',
#  'DAYS_REGISTRATION',
#  'DAYS_ID_PUBLISH',
#  'DAYS_LAST_PHONE_CHANGE']
