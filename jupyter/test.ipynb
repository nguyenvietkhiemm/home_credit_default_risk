# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import importlib
import gc
import io
import os

from config import ROOT, paths  # lib này được khởi tạo ban đầu dự án

from IPython.display import display

pd.set_option('display.max_columns', 99)
pd.set_option('display.max_rows', 200)

pd.reset_option('display.float_format')
pd.set_option('display.max_colwidth', None)


import helpers.view as view
import helpers.EDA as EDA
import modules.utils as utils
from config import app_categorical_features

importlib.reload(view)
importlib.reload(EDA)
importlib.reload(utils)

from helpers.cache_clear import cache_clear
for name, path in paths.items():
    if os.path.isfile(path):
        print(f"{name}: tồn tại")
    else:
        print(f"{name}: không tồn tại")
# Out:
# train: tồn tại
# test: tồn tại
# prev: tồn tại
# installments: tồn tại
# credit_card: tồn tại
# pos_cash: tồn tại
# bureau: tồn tại
# bureau_balance: tồn tại
# description: tồn tại

# %%
tmp = pd.read_pickle(ROOT + "/data/imputation_feature/train/interest_rate.p")

# %%
tmp
# Out:
#         SK_ID_CURR  pred_interest_rate  interest_rate_min  interest_rate_max  \
# 0           100002            0.035442       3.244954e-08           0.060109
# 1           100003            0.017941       1.368897e-08           0.022867
# 2           100004            0.016845       2.077129e-08           0.048782
# 3           100006            0.026399       1.243618e-07           0.094861
# 4           100007            0.024200       1.062504e-08           0.040729
# ...            ...                 ...                ...                ...
# 307506      456251            0.042559       1.823201e-07           0.108162
# 307507      456252            0.026830       1.775432e-08           0.042835
# 307508      456253            0.031920       1.646117e-08           0.042520
# 307509      456254            0.036170       2.074377e-08           0.053667
# 307510      456255            0.037975       3.714153e-08           0.072456
#
#         interest_rate_median  interest_rate_std
# 0                   0.054106           0.022489
# 1                   0.007063           0.009246
# 2                   0.040603           0.019153
# 3                   0.092643           0.029945
# 4                   0.030608           0.016505
# ...                      ...                ...
# 307506              0.106665           0.031650
# 307507              0.033256           0.017128
# 307508              0.032862           0.017031
# 307509              0.046500           0.021021
# 307510              0.068214           0.025774
#
# [307511 rows x 6 columns]

# %%
tmp[tmp["interest_rate_max"]>=0.12]
# Out:
#         SK_ID_CURR  interest_rate_min  interest_rate_max  \
# 605         100692       2.516313e-07           0.120083
# 2303        102695       1.973772e-07           0.120360
# 2690        103138       2.123996e-07           0.120600
# 3754        104382       2.473271e-07           0.120025
# 3896        104556       2.516313e-07           0.120083
# ...            ...                ...                ...
# 300382      448002       1.955668e-07           0.121372
# 301090      448822       2.462907e-07           0.120011
# 301148      448887       2.112996e-07           0.120583
# 304954      453313       2.471840e-07           0.121099
# 305316      453736       2.185586e-07           0.120694
#
#         interest_rate_median  interest_rate_std
# 605                 0.119033           0.033731
# 2303                0.119319           0.033784
# 2690                0.119567           0.033830
# 3754                0.118973           0.033720
# 3896                0.119033           0.033731
# ...                      ...                ...
# 300382              0.120362           0.033980
# 301090              0.118959           0.033717
# 301148              0.119549           0.033827
# 304954              0.120081           0.033927
# 305316              0.119663           0.033848
#
# [347 rows x 5 columns]

# %%
trte[trte["data"] == 1].to_pickle(ROOT + "/data/processed/f0012_train.p")

# %%
# from config import reload_config
# reload_config()

from config import reload
reload()
from config import use_cols

# %%
use_cols
