# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
from sitecustomize import ROOT # lib này được khởi tạo ban đầu dự án

# %%
from config.database.database import Database

# %%
db = Database()
# Out:
# Kết nối MySQL thành công!

# %%
# load theo từng batch tránh quá tải ram

import pandas as pd

def load_save(table_name=None, batch_size=100000):
    if not table_name:
        return

    file_path_csv = f"{ROOT}/data/csv/{table_name}.csv"
    file_path_pkl = f"{ROOT}/data/pkl/{table_name}.p"
    query = f"SELECT * FROM {table_name}"
    db.cursor.execute(query)

    columns = [desc[0] for desc in db.cursor.description]
    first_write = True
    dfs = []

    while True:
        data = db.cursor.fetchmany(batch_size)
        if not data:
            break

        df = pd.DataFrame(columns=columns, data=data)
        dfs.append(df) 

        df.to_csv(file_path_csv, mode="w" if first_write else "a", index=False, header=first_write)
        first_write = False
        print(f"Saved {len(data)} rows...")

    if dfs:
        pd.concat(dfs).to_pickle(file_path_pkl)
        print(f"Saved all data to {file_path_pkl}")

# %% [markdown]
# # get train data (application hiện tại)

# %%
load_save(table_name="application_train")
# Out:
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 7511 rows...
# Saved all data to d:\Data Science/data/pkl/application_train.p

# %% [markdown]
# # get test data (application hiện tại)

# %%
load_save(table_name="application_test")
# Out:
# Saved 48744 rows...
# Saved all data to d:\Data Science/data/pkl/application_test.p

# %% [markdown]
# # get previous application data (application trước đó)

# %%
load_save(table_name="previous_application")
# Out:
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 70214 rows...
# Saved all data to d:\Data Science/data/pkl/previous_application.p

# %% [markdown]
# # get bureau (các khoản tín dụng bên ngoài được báo cáo về)

# %%
load_save(table_name="bureau")
# Out:
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 16428 rows...
# Saved all data to d:\Data Science/data/pkl/bureau.p

# %% [markdown]
# # get bureau_balance (số dư hàng tháng của bureau)

# %%
load_save(table_name="bureau_balance")
# Out:
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 99925 rows...
# Saved all data to d:\Data Science/data/pkl/bureau_balance.p

# %% [markdown]
# # get credit card balance (số dư hàng tháng đối với các application trước đó)

# %%
load_save(table_name="credit_card_balance")
# Out:
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 40312 rows...
# Saved all data to d:\Data Science/data/pkl/credit_card_balance.p

# %% [markdown]
# # get installments payments (lịch sử trả tiền định kỳ cho các application trước đây được giải ngân)

# %%
load_save(table_name="installments_payments")
# Out:
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 5401 rows...
# Saved all data to d:\Data Science/data/pkl/installments_payments.p

# %% [markdown]
# # get pos cash balance (lịch sử số dư hàng tháng của các khoản vay tiêu dùng và vay tiền mặt mà khách hàng đã vay trước đó)

# %%
load_save(table_name="pos_cash_balance")
# Out:
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 100000 rows...
# Saved 1358 rows...
# Saved all data to d:\Data Science/data/pkl/pos_cash_balance.p

# %% [markdown]
# # get descriptions

# %%
load_save(table_name="homecredit_columns_description")
# Out:
# Saved 219 rows...
# Saved all data to d:\Data Science/data/pkl/homecredit_columns_description.p

# %%
df = pd.read_csv(ROOT + "/data/csv/homecredit_columns_description.csv")

# %%
df["Table"] = df["Table"].replace("application_{train|test}.csv", "train_test")

# %%
df
# Out:
#      MyUnknownColumn                      Table                    Row  \
# 0                  1                 train_test             SK_ID_CURR
# 1                  2                 train_test                 TARGET
# 2                  5                 train_test     NAME_CONTRACT_TYPE
# 3                  6                 train_test            CODE_GENDER
# 4                  7                 train_test           FLAG_OWN_CAR
# ..               ...                        ...                    ...
# 214              217  installments_payments.csv  NUM_INSTALMENT_NUMBER
# 215              218  installments_payments.csv        DAYS_INSTALMENT
# 216              219  installments_payments.csv     DAYS_ENTRY_PAYMENT
# 217              220  installments_payments.csv         AMT_INSTALMENT
# 218              221  installments_payments.csv            AMT_PAYMENT
#
#                                            Description  \
# 0                             ID of loan in our sample
# 1    Target variable (1 - client with payment diffi...
# 2          Identification if loan is cash or revolving
# 3                                 Gender of the client
# 4                        Flag if the client owns a car
# ..                                                 ...
# 214            On which installment we observe payment
# 215  When the installment of previous credit was su...
# 216  When was the installments of previous credit p...
# 217  What was the prescribed installment amount of ...
# 218  What the client actually paid on previous cred...
#
#                                    Special
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 214                                    NaN
# 215  time only relative to the application
# 216  time only relative to the application
# 217                                    NaN
# 218                                    NaN
#
# [219 rows x 5 columns]

# %%
tmp = df[df["Table"] == "train_test"]

# %%
tmp["Table"] = "test"
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12828\1039460742.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp["Table"] = "test"

# %%
tmp
# Out:
#      MyUnknownColumn Table                         Row  \
# 0                  1  test                  SK_ID_CURR
# 1                  2  test                      TARGET
# 2                  5  test          NAME_CONTRACT_TYPE
# 3                  6  test                 CODE_GENDER
# 4                  7  test                FLAG_OWN_CAR
# ..               ...   ...                         ...
# 117              120  test   AMT_REQ_CREDIT_BUREAU_DAY
# 118              121  test  AMT_REQ_CREDIT_BUREAU_WEEK
# 119              122  test   AMT_REQ_CREDIT_BUREAU_MON
# 120              123  test   AMT_REQ_CREDIT_BUREAU_QRT
# 121              124  test  AMT_REQ_CREDIT_BUREAU_YEAR
#
#                                            Description Special
# 0                             ID of loan in our sample     NaN
# 1    Target variable (1 - client with payment diffi...     NaN
# 2          Identification if loan is cash or revolving     NaN
# 3                                 Gender of the client     NaN
# 4                        Flag if the client owns a car     NaN
# ..                                                 ...     ...
# 117  Number of enquiries to Credit Bureau about the...     NaN
# 118  Number of enquiries to Credit Bureau about the...     NaN
# 119  Number of enquiries to Credit Bureau about the...     NaN
# 120  Number of enquiries to Credit Bureau about the...     NaN
# 121  Number of enquiries to Credit Bureau about the...     NaN
#
# [122 rows x 5 columns]

# %%
tmp = tmp[tmp["Row"] != "TARGET"]

# %%
df = pd.concat([df, tmp])

# %%
df = df.replace("train_test", "train")

# %%
df["Table"] = df["Table"].str.replace(r".csv$", "", regex=True)

# %%
df
# Out:
#      MyUnknownColumn  Table                         Row  \
# 0                  1  train                  SK_ID_CURR
# 1                  2  train                      TARGET
# 2                  5  train          NAME_CONTRACT_TYPE
# 3                  6  train                 CODE_GENDER
# 4                  7  train                FLAG_OWN_CAR
# ..               ...    ...                         ...
# 117              120   test   AMT_REQ_CREDIT_BUREAU_DAY
# 118              121   test  AMT_REQ_CREDIT_BUREAU_WEEK
# 119              122   test   AMT_REQ_CREDIT_BUREAU_MON
# 120              123   test   AMT_REQ_CREDIT_BUREAU_QRT
# 121              124   test  AMT_REQ_CREDIT_BUREAU_YEAR
#
#                                            Description Special
# 0                             ID of loan in our sample     NaN
# 1    Target variable (1 - client with payment diffi...     NaN
# 2          Identification if loan is cash or revolving     NaN
# 3                                 Gender of the client     NaN
# 4                        Flag if the client owns a car     NaN
# ..                                                 ...     ...
# 117  Number of enquiries to Credit Bureau about the...     NaN
# 118  Number of enquiries to Credit Bureau about the...     NaN
# 119  Number of enquiries to Credit Bureau about the...     NaN
# 120  Number of enquiries to Credit Bureau about the...     NaN
# 121  Number of enquiries to Credit Bureau about the...     NaN
#
# [340 rows x 5 columns]

# %%
df.to_csv(ROOT + "/data/csv/description.csv", index=False)
df.to_pickle(ROOT + "/data/pkl/description.p")
